# %%
import mip
import pickle

# %%
with open("output.pkl","rb") as f:
    dic = pickle.load(f)

# %%
dic
# Out:
# {'000000': [[0.33333333333340454, 0.3333333333334678, 0.3333333333333434],
#   [0.3333333333333253, 0.3333333333331383, 0.33333333333327014],
#   [0.3333333333332702, 0.3333333333333939, 0.33333333333328574]],
#  '000001': [[0.3333333333331924, 0.33333333333324566, 0.3333333333333787],
#   [0.33333333333369036, 0.33333333333295706, 0.3333333333334361],
#   [0.33333333333365567, 0.3333333333331592, 0.3333333333331852]],
#  '000002': [[0.3333333333334061, 0.333333333333534, 0.333333333333444],
#   [0.333333333333297, 0.333333333333169, 0.33333333333337084],
#   [0.33333333333329684, 0.333333333333297, 0.3333333333331852]],
#  '000003': [[0.3333333333337117, 0.3333333333332916, 0.3333333333333787],
#   [0.3333333333332084, 0.33333333333355636, 0.33333333333323517],
#   [0.33333333333346177, 0.333333333333152, 0.33333333333338616]],
#  '000004': [[0.3333333333336842, 0.3333333333332933, 0.3333333333330225],
#   [0.3333333333328544, 0.33333333333340776, 0.33333333333366194],
# ...
